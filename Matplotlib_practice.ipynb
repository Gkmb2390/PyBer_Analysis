# %%
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis, y_axis)

# %%
# %matplotlib inline

# %%
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Alternative method to fig, ax = plt.subplots()
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
fig = plt.figure()

# %% [markdown]
# # PLT Show

# %%
# create the plot
plt.plot(x_axis, y_axis)
plt.show()

# %% [markdown]
# Adding Legends and Labels

# %%
# Create the plot and add a label for the legend
plt.plot(x_axis, y_axis, label='Boston')
#Create Labels for X & Y
plt.xlabel('Date')
plt.ylabel('Fare($)')
#SEt the Y limit between 0 & 45
plt.ylim(0,45)
#Create a Title
plt.title("PyBer Fare by Month")
#Add a legend
plt.legend()

# %% [markdown]
# Changing the line markings

# %%
# Create the Plot
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
#Create Labels for X & Y
plt.xlabel('Date')
plt.ylabel('Fare($)')
#SEt the Y limit between 0 & 45
plt.ylim(0,45)
#Create a Title
plt.title("PyBer Fare by Month")
#Add a legend
plt.legend()

# %% [markdown]
# Skill Drill 5.1.4

# %%
# Create the Plot
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis, marker="D", color="green", linewidth=2, label='Boston')
#Create Labels for X & Y
ax.set_xlabel("Date")
ax.set_ylabel("Fare($)")
#SEt the Y limit between 0 & 45
ax.set_ylim(0,45)
#Create a Title
ax.set_title("PyBer Fare by Month")
#Add a legend
ax.legend()
#grid lines
ax.grid()

plt.show()

# %% [markdown]
# Bar Charts

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %% [markdown]
# Vertical Bar Charts

# %%
#create the plot
plt.bar(x_axis, y_axis, color="green", label = 'Boston')
#create labels for the x and y axes
plt.xlabel("Date")
plt.ylabel("Fare($)")
#Create a Title
plt.title("Pyber Fare by Month")
#Add a legend
plt.legend()

# %% [markdown]
# Horizontal Bar Chart

# %%
# Create the Plot
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the Plot
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %% [markdown]
# Skill Challenge 5.1.5

# %%
# Create the Plot
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color="magenta", label ="Boston")
ax.invert_yaxis()
ax.set_title ("Pyber Fare by Month")
ax.set_xlabel ("Fare($)")
ax.set_ylabel("Date")
plt.show()

# %% [markdown]
# # Object Oriented Approach

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot with Ax.plot
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#Create Horizontal Bar Graph
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# Skill drill 5.1.6

# %%
#Create Horizontal Bar Graph
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis, label = "Chicago", color="cyan")
ax.set_xlabel("Fare($)")
ax.set_ylabel("Date")
# Out:
# Text(0, 0.5, 'Date')

# %% [markdown]
# SCATTER PLOTS

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis, y_axis, 'o')

# %%
plt.scatter(x_axis, y_axis)

# %% [markdown]
# skill drill 5.1.7

# %%
plt.scatter(y_axis,x_axis,  label='Chicago', color='red')
plt.title("Pyber Fare by Month")
plt.xlabel("Fare")
plt.ylabel('Date')
plt.gca().invert_yaxis()

# %% [markdown]
# # Bubble Chart

# %%
plt.scatter(x_axis, y_axis, s=y_axis)

# %% [markdown]
# INCREASE THE SIZE OF THE DOT FOR LEGIBILITY

# %%
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)

# %%
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
plt.scatter(x_axis, y_axis, s=[i*3 for i in y_axis])

# %% [markdown]
# # scatter plots with Object Oritented

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %% [markdown]
# Bubble Chart wit Object Oriented

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %% [markdown]
# Skill Drill 5.1.7

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=[i*5 for i in y_axis], color = "skyblue", linewidth = 2, label = "Boston")
ax.set_title("Pyber Fare by Month")
ax.set_xlim(0,50)
Axes.invert_yaxis()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1052/1450052007.py in <module>
#       3 ax.set_title("Pyber Fare by Month")
#       4 ax.set_xlim(0,50)
# ----> 5 Axes.invert_yaxis()
#
# NameError: name 'Axes' is not defined

# %% [markdown]
# Pie Chart

# %%
plt.subplots(figsize=(8,8))
colors =["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0,0,0,0,0,0,.4,0,0,0,0,0,)
plt.pie(y_axis, labels = x_axis, explode = explode_values, autopct='%.1f%%', colors = colors)

plt.show()

# %% [markdown]
# OO Pie Chart Skill drill 5.1.8

# %%
explode_values = (0,0,.4,0,0,0,.4,0,0,0,0,0,)
fig, ax = plt.subplots(figsize = (8,8))
ax.pie(y_axis, labels = x_axis,autopct='%.1f%%', explode = explode_values, startangle=100, counterclock=False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Error Bars on Line Charts

# %%
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1052/1634209975.py in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 plt.errorbar()
#
# TypeError: errorbar() missing 2 required positional arguments: 'x' and 'y'

# %%
import matplotlib.pyplot as plt
import statistics

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Get the Standar dev of values in y axis
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
plt.errorbar(x_axis, y_axis, yerr = stdev, capsize = 3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# OO Error Line Chart

# %%
fig, ax = plt.subplots()
ax.errorbar(x_axis, y_axis, yerr=stdev, capsize = 3)
plt.show()

# %% [markdown]
# Error Bar Charts

# %%
plt.bar(x_axis, y_axis, yerr=stdev, capsize = 3)
# Out:
# <BarContainer object of 12 artists>

# %%
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, yerr=stdev, capsize = 3)
plt.show()

# %% [markdown]
# Change major ticks

# %%
import numpy as np
plt.barh(x_axis, y_axis)

# %%
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step = 5.0))
#alternative SET X ticks formulas
# ax.xaxis.set_ticks()
plt.show()

# %% [markdown]
# ADD MINOR TICKS

# %%
from matplotlib.ticker import MultipleLocator
#increase the size of the plot figure
fig, ax = plt.subplots(figsize=(8,8))
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0,51, step=5.0))

# Create minor ticks at 1 increment
ax.xaxis.set_minor_locator(MultipleLocator(1))
plt.show()
